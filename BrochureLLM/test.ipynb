# %%
from Components.LLM import LLM

def main():
  name = str(input("Enter the Website Name:"))
  link = str(input("Enter Website URL:"))
  l = LLM(name if name else "NECN",link if link else "https://necn.ac.in")
  l.create_brochure()

if __name__=="__main__":
  main()
# Out:
# # **Narayana Engineering College – NECN**
# > *“Engineering 4.0. Shaping Tomorrow.”*
#
# ![Narc-neutral campus image placeholder]()
#
# *(Scroll or download the PDF version for a printable layout.)*
#
# ---
#
# ## 📚 Table of Contents
# 1. [About NECN](#about-necn)
# 2. [Vision & Mission](#vision‑and‑mission)
# 3. [Academic Programs](#academic-programs)
# 4. [Admissions & Fees](#admissions‑&‑fees)
# 5. [Research & Innovation](#research‑&‑innovation)
# 6. [Student Life & Clubs](#student‑life‑&‑clubs)
# 7. [Placements & Career Development](#placements‑&‑career-development)
# 8. [Infrastructure & Facilities](#infrastructure‑&‑facilities)
# 9. [Governance & Accreditation](#governance‑&‑accreditation)
# 10. [Alumni & Outreach](#alumni‑&‑outreach)
# 11. [Contact & Social Media](#contact‑&‑social-media)
#
# ---
#
# ## 🏛️ About NECN
# - **Location:** Nellore, Andhra Pradesh
# - **Affiliation:** *[Message]* (link to *affiliated‑university*)
# - **Established:** 1997
# ...
